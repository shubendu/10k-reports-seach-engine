# %%
import requests
import json

url = "http://44.193.54.227:8000/backend/download_table"

payload = json.dumps({
  "elastic_indx": "10k",
  "ids": [
    "2ef0659b48bfb8c490245864ac260a11_117_t_0"
  ],
  "select_fields": [
    "id",
    "PDF",
    "page",
    "table_png",
    "table_xml",
    "table_xls",
    "table_html",
    "table_np"
  ],
  "format": [
    ".png",
    ".xml",
    ".xls",
    ".html",
    ".np"
  ]
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Token 26f9b124da0da589be592f666da4f45c3981f355'
}

response = requests.request("POST", url, headers=headers, data=payload)

dd = response.json()

# %%
dd
# Out:
# {'ok': True,
#  'error': '',
#  'columns': {'id': 'text',
#   'PDF': 'keyword',
#   'page': 'long',
#   'table_png': 'binary',
#   'table_xml': 'binary',
#   'table_xls': 'binary',
#   'table_html': 'binary',
#   'table_np': 'text'},
#  'data': [{'id': '2ef0659b48bfb8c490245864ac260a11_117_t_0',
#    'PDF': 'CNO_finacial_group_10k.pdf',
#    'page': 117,
#    'table_png': '...',
#    'table_xml': '...',
#    'table_xls': '...',
#    'table_html': '...',
#    'table_np': '[[["None", ""], ["1", "2017"], ["2", "2016"]], [["3", "Investments:"], ["None", ""], ["None", ""]], [["4", "Fixed maturities, available for sale, at fair value (amortized cost: 2017- $20,702.1; 2016- $19,803.1)"], ["5", "$ 22,910.9"], ["6", "$ 21,096.2"]], [["7", "Equity securities at fair value (cost: 2017- $491.1; 2016- $580.7)"], ["8", "511.7"], ["9", "584.2"]], [["10", "Mortgage loans"], ["11", "1,650.6"], ["12", "1,768.0"]], [["13", "Policy loans"], ["14", "116.0"], ["15", "112.0"]], [["16", "Trading securities"], ["17", "284.6"], ["18", "363.4"]], [["19", "Investments held by variable interest entities"], ["20", "1,526.9"], ["21", "1,724.3"]], [["22", "Other invested assets"], ["23", "853.4"], ["24", "589.5"]], [["25", "Total investments"], ["26", "27,854.1"], ["27", "26,237.6"]], [["28", "Cash and cash equivalents- unrestricted"], ["29", "578.4"], ["30", "478.9"]], [["31", "Cash and cash equivalents held by variable interest entities"], ["32", "178.9"], ["33", "189.3"]], [["34", "Accrued investment income"], ["35", "245.9"], ["36", "239.6"]], [["37", "Present value of future profits"], ["38", "359.6"], ["39", "401.8"]], [["40", "Deferred acquisition costs"], ["41", "1,026.8"], ["42", "1,044.7"]], [["43", "Reinsurance receivables"], ["44", "2,175.2"], ["45", "2,260.4"]], [["46", "Income tax assets, net"], ["47", "366.9"], ["48", "789.7"]], [["49", "Assets held in separate accounts"], ["50", "5.0"], ["51", "4.7"]], [["52", "Other assets"], ["53", "319.5"], ["54", "328.5"]], [["55", "Total assets"], ["56", "$ 33,110.3"], ["57", "$ 31,975.2"]]]'}],
#  'payload': {'elastic_indx': '10k',
#   'ids': ['2ef0659b48bfb8c490245864ac260a11_117_t_0'],
#   'select_fields': ['id',
#    'PDF',
#    'page',
#    'table_png',
#    'table_xml',
#    'table_xls',
#    'table_html',
#    'table_np',
#    'table_png',
#    'table_xml',
#    'table_xls',
#    'table_html',
#    'table_np'],
#   'format': ['.png', '.xml', '.xls', '.html', '.np'],
#   'user_id': 2}}

# %%
dd['data'][0]['table_np']
# Out:
# '[[["None", ""], ["1", "2017"], ["2", "2016"]], [["3", "Investments:"], ["None", ""], ["None", ""]], [["4", "Fixed maturities, available for sale, at fair value (amortized cost: 2017- $20,702.1; 2016- $19,803.1)"], ["5", "$ 22,910.9"], ["6", "$ 21,096.2"]], [["7", "Equity securities at fair value (cost: 2017- $491.1; 2016- $580.7)"], ["8", "511.7"], ["9", "584.2"]], [["10", "Mortgage loans"], ["11", "1,650.6"], ["12", "1,768.0"]], [["13", "Policy loans"], ["14", "116.0"], ["15", "112.0"]], [["16", "Trading securities"], ["17", "284.6"], ["18", "363.4"]], [["19", "Investments held by variable interest entities"], ["20", "1,526.9"], ["21", "1,724.3"]], [["22", "Other invested assets"], ["23", "853.4"], ["24", "589.5"]], [["25", "Total investments"], ["26", "27,854.1"], ["27", "26,237.6"]], [["28", "Cash and cash equivalents- unrestricted"], ["29", "578.4"], ["30", "478.9"]], [["31", "Cash and cash equivalents held by variable interest entities"], ["32", "178.9"], ["33", "189.3"]], [["34", "Accrued investment income"], ["35", "245.9"], ["36", "239.6"]], [["37", "Present value of future profits"], ["38", "359.6"], ["39", "401.8"]], [["40", "Deferred acquisition costs"], ["41", "1,026.8"], ["42", "1,044.7"]], [["43", "Reinsurance receivables"], ["44", "2,175.2"], ["45", "2,260.4"]], [["46", "Income tax assets, net"], ["47", "366.9"], ["48", "789.7"]], [["49", "Assets held in separate accounts"], ["50", "5.0"], ["51", "4.7"]], [["52", "Other assets"], ["53", "319.5"], ["54", "328.5"]], [["55", "Total assets"], ["56", "$ 33,110.3"], ["57", "$ 31,975.2"]]]'

# %%
import numpy as np

# %%
final =  np.array(json.loads(dd['data'][0]['table_np']))
final.shape
# Out:
# (20, 3, 2)

# %%
final
# Out:
# array([[['None', ''],
#         ['1', '2017'],
#         ['2', '2016']],
#
#        [['3', 'Investments:'],
#         ['None', ''],
#         ['None', '']],
#
#        [['4',
#          'Fixed maturities, available for sale, at fair value (amortized cost: 2017- $20,702.1; 2016- $19,803.1)'],
#         ['5', '$ 22,910.9'],
#         ['6', '$ 21,096.2']],
#
#        [['7',
#          'Equity securities at fair value (cost: 2017- $491.1; 2016- $580.7)'],
#         ['8', '511.7'],
#         ['9', '584.2']],
#
#        [['10', 'Mortgage loans'],
#         ['11', '1,650.6'],
#         ['12', '1,768.0']],
#
#        [['13', 'Policy loans'],
#         ['14', '116.0'],
#         ['15', '112.0']],
#
#        [['16', 'Trading securities'],
#         ['17', '284.6'],
#         ['18', '363.4']],
#
#        [['19', 'Investments held by variable interest entities'],
#         ['20', '1,526.9'],
#         ['21', '1,724.3']],
#
#        [['22', 'Other invested assets'],
#         ['23', '853.4'],
#         ['24', '589.5']],
#
#        [['25', 'Total investments'],
#         ['26', '27,854.1'],
#         ['27', '26,237.6']],
#
#        [['28', 'Cash and cash equivalents- unrestricted'],
#         ['29', '578.4'],
#         ['30', '478.9']],
#
#        [['31',
#          'Cash and cash equivalents held by variable interest entities'],
#         ['32', '178.9'],
#         ['33', '189.3']],
#
#        [['34', 'Accrued investment income'],
#         ['35', '245.9'],
#         ['36', '239.6']],
#
#        [['37', 'Present value of future profits'],
#         ['38', '359.6'],
#         ['39', '401.8']],
#
#        [['40', 'Deferred acquisition costs'],
#         ['41', '1,026.8'],
#         ['42', '1,044.7']],
#
#        [['43', 'Reinsurance receivables'],
#         ['44', '2,175.2'],
#         ['45', '2,260.4']],
#
#        [['46', 'Income tax assets, net'],
#         ['47', '366.9'],
#         ['48', '789.7']],
#
#        [['49', 'Assets held in separate accounts'],
#         ['50', '5.0'],
#         ['51', '4.7']],
#
#        [['52', 'Other assets'],
#         ['53', '319.5'],
#         ['54', '328.5']],
#
#        [['55', 'Total assets'],
#         ['56', '$ 33,110.3'],
#         ['57', '$ 31,975.2']]], dtype='<U102')

# %%
final[7]
# Out:
# array([['19', 'Investments held by variable interest entities'],
#        ['20', '1,526.9'],
#        ['21', '1,724.3']], dtype='<U102')

# %%
final[8]
# Out:
# array([['22', 'Other invested assets'],
#        ['23', '853.4'],
#        ['24', '589.5']], dtype='<U102')

# %%
final.shape[0]
# Out:
# 20

# %%
final[0][0]
# Out:
# array(['None', ''], dtype='<U102')

# %%
final[0].shape[0]
# Out:
# 3

# %%
'None' in list(final[0][0])
# Out:
# True

# %%
aa = final[2][1][1].split()[1].split(",")
float("".join(aa))
# Out:
# 22910.9

# %%
for i in range(final.shape[0]):
    for j in range(final[i].shape[0]):
        if 'None' in list(final[i][j]):
            continue
        print(final[i][j])
    print("="*20)
# Out:
# ['1' '2017']
# ['2' '2016']
# ====================
# ['3' 'Investments:']
# ====================
# ['4'
#  'Fixed maturities, available for sale, at fair value (amortized cost: 2017- $20,702.1; 2016- $19,803.1)']
# ['5' '$ 22,910.9']
# ['6' '$ 21,096.2']
# ====================
# ['7' 'Equity securities at fair value (cost: 2017- $491.1; 2016- $580.7)']
# ['8' '511.7']
# ['9' '584.2']
# ====================
# ['10' 'Mortgage loans']
# ['11' '1,650.6']
# ['12' '1,768.0']
# ====================
# ['13' 'Policy loans']
# ['14' '116.0']
# ['15' '112.0']
# ====================
# ['16' 'Trading securities']
# ['17' '284.6']
# ['18' '363.4']
# ====================
# ['19' 'Investments held by variable interest entities']
# ['20' '1,526.9']
# ['21' '1,724.3']
# ====================
# ['22' 'Other invested assets']
# ['23' '853.4']
# ['24' '589.5']
# ====================
# ['25' 'Total investments']
# ['26' '27,854.1']
# ['27' '26,237.6']
# ====================
# ['28' 'Cash and cash equivalents- unrestricted']
# ['29' '578.4']
# ['30' '478.9']
# ====================
# ['31' 'Cash and cash equivalents held by variable interest entities']
# ['32' '178.9']
# ['33' '189.3']
# ====================
# ['34' 'Accrued investment income']
# ['35' '245.9']
# ['36' '239.6']
# ====================
# ['37' 'Present value of future profits']
# ['38' '359.6']
# ['39' '401.8']
# ====================
# ['40' 'Deferred acquisition costs']
# ['41' '1,026.8']
# ['42' '1,044.7']
# ====================
# ['43' 'Reinsurance receivables']
# ['44' '2,175.2']
# ['45' '2,260.4']
# ====================
# ['46' 'Income tax assets, net']
# ['47' '366.9']
# ['48' '789.7']
# ====================
# ['49' 'Assets held in separate accounts']
# ['50' '5.0']
# ['51' '4.7']
# ====================
# ['52' 'Other assets']
# ['53' '319.5']
# ['54' '328.5']
# ====================
# ['55' 'Total assets']
# ['56' '$ 33,110.3']
# ['57' '$ 31,975.2']
# ====================
