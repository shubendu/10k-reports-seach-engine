# %%
import requests
import json

url = "http://44.193.54.227:8000/backend/download_table"

payload = json.dumps({
  "elastic_indx": "10k",
  "ids": [
    "2ef0659b48bfb8c490245864ac260a11_118_t_0"
  ],
  "select_fields": [
    "id",
    "PDF",
    "page",
    "table_png",
    "table_xml",
    "table_xls",
    "table_html",
    "table_np"
  ],
  "format": [
    ".png",
    ".xml",
    ".xls",
    ".html",
    ".np"
  ]
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Token 26f9b124da0da589be592f666da4f45c3981f355'
}

response = requests.request("POST", url, headers=headers, data=payload)

dd = response.json()

# %%
dd
# Out:
# {'ok': True,
#  'error': '',
#  'columns': {'id': 'text',
#   'PDF': 'keyword',
#   'page': 'long',
#   'table_png': 'binary',
#   'table_xml': 'binary',
#   'table_xls': 'binary',
#   'table_html': 'binary',
#   'table_np': 'text'},
#  'data': [{'id': '2ef0659b48bfb8c490245864ac260a11_118_t_0',
#    'PDF': 'CNO_finacial_group_10k.pdf',
#    'page': 118,
#    'table_png': '...',
#    'table_xml': '...',
#    'table_xls': '...',
#    'table_html': '...',
#    'table_np': '[[["None", ""], ["1", "2017"], ["2", "2016"]], [["3", "Liabilities:"], ["None", ""], ["None", ""]], [["4", "Liabilities for insurance products:"], ["None", ""], ["None", ""]], [["5", "Policyholder account balances"], ["6", "$ 11,220.7"], ["7", "$ 10,912.7"]], [["8", "Future policy benefits"], ["9", "11,521.3"], ["10", "10,953.3"]], [["11", "Liability for policy and contract claims"], ["12", "530.3"], ["13", "500.6"]], [["14", "Unearned and advanced premiums"], ["15", "261.7"], ["16", "282.5"]], [["17", "Liabilities related to separate accounts"], ["18", "5.0"], ["19", "4.7"]], [["20", "Other liabilities"], ["21", "751.8"], ["22", "611.4"]], [["23", "Investment borrowings"], ["24", "1,646.7"], ["25", "1,647.4"]], [["26", "Borrowings related to variable interest entities"], ["27", "1,410.7"], ["28", "1,662.8"]], [["29", "Notes payable \\u00e2\\u0080\\u0093 direct corporate obligations"], ["30", "914.6"], ["31", "912.9"]], [["32", "Total liabilities"], ["33", "28,262.8"], ["34", "27,488.3"]], [["35", "Commitments and Contingencies Shareholders\' equity:"], ["None", ""], ["None", ""]], [["36", "Common stock ($0.01 par value, 8,000,000,000 shares authorized, shares issued and outstanding: 2017- 166,857,931; 2016- 173,753,614)"], ["37", "1.7"], ["38", "1.7"]], [["39", "Additional paid-in capital"], ["40", "3,073.3"], ["41", "3,212.1"]], [["42", "Accumulated other comprehensive income"], ["43", "1,212.1"], ["44", "622.4"]], [["45", "Retained earnings"], ["46", "560.4"], ["47", "650.7"]], [["48", "Total shareholders\' equity"], ["49", "4,847.5"], ["50", "4,486.9"]], [["51", "Total liabilities and shareholders\' equity"], ["52", "$ 33,110.3"], ["53", "$ 31,975.2"]]]'}],
#  'payload': {'elastic_indx': '10k',
#   'ids': ['2ef0659b48bfb8c490245864ac260a11_118_t_0'],
#   'select_fields': ['id',
#    'PDF',
#    'page',
#    'table_png',
#    'table_xml',
#    'table_xls',
#    'table_html',
#    'table_np',
#    'table_png',
#    'table_xml',
#    'table_xls',
#    'table_html',
#    'table_np'],
#   'format': ['.png', '.xml', '.xls', '.html', '.np'],
#   'user_id': 2}}

# %%
dd['data'][0]['table_np']
# Out:
# '[[["None", ""], ["1", "2017"], ["2", "2016"]], [["3", "Liabilities:"], ["None", ""], ["None", ""]], [["4", "Liabilities for insurance products:"], ["None", ""], ["None", ""]], [["5", "Policyholder account balances"], ["6", "$ 11,220.7"], ["7", "$ 10,912.7"]], [["8", "Future policy benefits"], ["9", "11,521.3"], ["10", "10,953.3"]], [["11", "Liability for policy and contract claims"], ["12", "530.3"], ["13", "500.6"]], [["14", "Unearned and advanced premiums"], ["15", "261.7"], ["16", "282.5"]], [["17", "Liabilities related to separate accounts"], ["18", "5.0"], ["19", "4.7"]], [["20", "Other liabilities"], ["21", "751.8"], ["22", "611.4"]], [["23", "Investment borrowings"], ["24", "1,646.7"], ["25", "1,647.4"]], [["26", "Borrowings related to variable interest entities"], ["27", "1,410.7"], ["28", "1,662.8"]], [["29", "Notes payable \\u00e2\\u0080\\u0093 direct corporate obligations"], ["30", "914.6"], ["31", "912.9"]], [["32", "Total liabilities"], ["33", "28,262.8"], ["34", "27,488.3"]], [["35", "Commitments and Contingencies Shareholders\' equity:"], ["None", ""], ["None", ""]], [["36", "Common stock ($0.01 par value, 8,000,000,000 shares authorized, shares issued and outstanding: 2017- 166,857,931; 2016- 173,753,614)"], ["37", "1.7"], ["38", "1.7"]], [["39", "Additional paid-in capital"], ["40", "3,073.3"], ["41", "3,212.1"]], [["42", "Accumulated other comprehensive income"], ["43", "1,212.1"], ["44", "622.4"]], [["45", "Retained earnings"], ["46", "560.4"], ["47", "650.7"]], [["48", "Total shareholders\' equity"], ["49", "4,847.5"], ["50", "4,486.9"]], [["51", "Total liabilities and shareholders\' equity"], ["52", "$ 33,110.3"], ["53", "$ 31,975.2"]]]'

# %%
import numpy as np

# %%
final =  np.array(json.loads(dd['data'][0]['table_np']))
final.shape
# Out:
# (20, 3, 2)

# %%
final
# Out:
# array([[['None', ''],
#         ['1', '2017'],
#         ['2', '2016']],
#
#        [['3', 'Liabilities:'],
#         ['None', ''],
#         ['None', '']],
#
#        [['4', 'Liabilities for insurance products:'],
#         ['None', ''],
#         ['None', '']],
#
#        [['5', 'Policyholder account balances'],
#         ['6', '$ 11,220.7'],
#         ['7', '$ 10,912.7']],
#
#        [['8', 'Future policy benefits'],
#         ['9', '11,521.3'],
#         ['10', '10,953.3']],
#
#        [['11', 'Liability for policy and contract claims'],
#         ['12', '530.3'],
#         ['13', '500.6']],
#
#        [['14', 'Unearned and advanced premiums'],
#         ['15', '261.7'],
#         ['16', '282.5']],
#
#        [['17', 'Liabilities related to separate accounts'],
#         ['18', '5.0'],
#         ['19', '4.7']],
#
#        [['20', 'Other liabilities'],
#         ['21', '751.8'],
#         ['22', '611.4']],
#
#        [['23', 'Investment borrowings'],
#         ['24', '1,646.7'],
#         ['25', '1,647.4']],
#
#        [['26', 'Borrowings related to variable interest entities'],
#         ['27', '1,410.7'],
#         ['28', '1,662.8']],
#
#        [['29', 'Notes payable â\x80\x93 direct corporate obligations'],
#         ['30', '914.6'],
#         ['31', '912.9']],
#
#        [['32', 'Total liabilities'],
#         ['33', '28,262.8'],
#         ['34', '27,488.3']],
#
#        [['35', "Commitments and Contingencies Shareholders' equity:"],
#         ['None', ''],
#         ['None', '']],
#
#        [['36',
#          'Common stock ($0.01 par value, 8,000,000,000 shares authorized, shares issued and outstanding: 2017- 166,857,931; 2016- 173,753,614)'],
#         ['37', '1.7'],
#         ['38', '1.7']],
#
#        [['39', 'Additional paid-in capital'],
#         ['40', '3,073.3'],
#         ['41', '3,212.1']],
#
#        [['42', 'Accumulated other comprehensive income'],
#         ['43', '1,212.1'],
#         ['44', '622.4']],
#
#        [['45', 'Retained earnings'],
#         ['46', '560.4'],
#         ['47', '650.7']],
#
#        [['48', "Total shareholders' equity"],
#         ['49', '4,847.5'],
#         ['50', '4,486.9']],
#
#        [['51', "Total liabilities and shareholders' equity"],
#         ['52', '$ 33,110.3'],
#         ['53', '$ 31,975.2']]], dtype='<U132')

# %%
final[7]
# Out:
# array([['17', 'Liabilities related to separate accounts'],
#        ['18', '5.0'],
#        ['19', '4.7']], dtype='<U132')

# %%
final[8]
# Out:
# array([['20', 'Other liabilities'],
#        ['21', '751.8'],
#        ['22', '611.4']], dtype='<U132')
